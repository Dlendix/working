# %% [markdown]
# # 🧠 Полная заготовка для решения задач на алгоритмы
#
# Этот ноутбук поможет вам структурировать подход к решению алгоритмических задач. Мы рассмотрим все этапы — от понимания задачи до сдачи решения. Также приведены примеры задач с олимпиад и их решения.

# %% [markdown]
# ## 1. Понимание задачи

# %% [markdown]
# ### Что нужно сделать:
# - Внимательно прочитать условие.
# - Определить:
#   - Формат входных данных (например, `n`, `arr`, `edges`).
#   - Формат выходных данных (например, `int`, `list`, `YES/NO`).
#   - Ограничения: `n <= 10^5`, `time limit: 2s`, `memory limit: 256MB`.
#   - Примеры: разобрать вручную.
#   - Краевые случаи: `n=0`, `n=1`, `пустой граф`, `одинаковые элементы`.

# %% [markdown]
# ### Пример задачи:
#
# **Задача A: Две суммы**
#
# Дан массив целых чисел `nums` и целевое число `target`. Найдите индексы двух чисел, сумма которых равна `target`.
#
# #### Вход:
# ```
# 4
# 2 7 11 15
# 9
# ```
#
# #### Выход:
# ```
# 0 1
# ```
#
# #### Пояснение:
# - `nums[0] + nums[1] = 2 + 7 = 9 = target`
# - Вывод: `0 1`

# %% [markdown]
# ## 2. Анализ и выбор подхода

# %% [markdown]
# ### Тип задачи:
# - Массивы, хэш-таблицы, поиск.
#
# ### Алгоритм:
# - Пройтись по массиву, для каждого элемента `x` искать `target - x` в хэш-таблице.
# - Время: `O(n)`, Память: `O(n)`.
#
# ### Краевые случаи:
# - Одинаковые числа.
# - Решение не существует (необязательно, если задача гарантирует решение).

# %% [markdown]
# ## 3. План решения

# %% [markdown]
# 1. Прочитать `n`, `nums`, `target`.
# 2. Создать пустой словарь `seen`.
# 3. Пройтись по индексам и значениям массива `nums`.
# 4. Если `target - nums[i]` есть в `seen`, вывести индексы.
# 5. Иначе, сохранить `nums[i]` и `i` в `seen`.

# %% [markdown]
# ## 4. Реализация на Python

# %%
def solve():
    n = int(input())
    nums = list(map(int, input().split()))
    target = int(input())
    
    seen = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in seen:
            print(seen[complement], i)
            return
        seen[num] = i

if __name__ == "__main__":
    solve()

# %% [markdown]
# ## 5. Тестирование

# %% [markdown]
# ### Тест 1:
# ```
# Вход:
# 4
# 2 7 11 15
# 9
# Выход:
# 0 1
# ```
#
# ### Тест 2 (краевой):
# ```
# Вход:
# 2
# 3 3
# 6
# Выход:
# 0 1
# ```

# %% [markdown]
# ## 6. Оптимизация

# %% [markdown]
# - Использование `dict` для поиска за `O(1)`.
# - Не используем вложенные циклы (`O(n^2)`).

# %% [markdown]
# ## 7. Сдача решения

# %% [markdown]
# - Убедиться, что вывод в точности соответствует формату.
# - Удалить отладочные `print`.
# - Проверить, что `import` не требуются (если не используются).

# %% [markdown]
# ## Часто используемые шаблоны

# %% [markdown]
# ### Бинарный поиск (левый)

# %%
def binary_search_left(arr, target):
    left, right = 0, len(arr)
    while left < right:
        mid = (left + right) // 2
        if arr[mid] < target:
            left = mid + 1
        else:
            right = mid
    return left

# %% [markdown]
# ### BFS (поиск в ширину)

# %%
from collections import deque

def bfs(graph, start):
    queue = deque([start])
    visited = set([start])
    while queue:
        node = queue.popleft()
        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
    return visited

# %% [markdown]
# ### DFS (поиск в глубину)

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    for neighbor in graph[start]:
        if neighbor not in visited:
            dfs(graph, neighbor, visited)
    return visited

# %% [markdown]
# ## Пример задачи: Динамическое программирование

# %% [markdown]
# ### Задача: Лестница (LeetCode 70. Climbing Stairs)
#
# Вы поднимаетесь по лестнице. Чтобы попасть на `n`-ую ступень, можно подняться на 1 или 2 ступени за раз. Сколько различных способов подняться на `n`-ую ступень?
#
# #### Вход:
# ```
# n = 3
# ```
#
# #### Выход:
# ```
# 3
# ```
#
# #### Объяснение:
# 1. 1 + 1 + 1
# 2. 1 + 2
# 3. 2 + 1

# %%
def climbStairs(n):
    if n <= 2:
        return n
    prev2, prev1 = 1, 2
    for _ in range(3, n + 1):
        current = prev1 + prev2
        prev2, prev1 = prev1, current
    return prev1

n = int(input())
print(climbStairs(n))

# %% [markdown]
# ## Пример задачи: Графы (DFS/BFS)

# %% [markdown]
# ### Задача: Подсчет компонент связности
#
# Дан неориентированный граф. Найдите количество компонент связности.
#
# #### Вход:
# ```
# n = 5
# m = 3
# edges = [(0, 1), (1, 2), (3, 4)]
# ```
#
# #### Выход:
# ```
# 2
# ```
#
# #### Объяснение:
# Компоненты: {0,1,2}, {3,4}

# %%
from collections import defaultdict, deque

def count_components(n, edges):
    graph = defaultdict(list)
    for u, v in edges:
        graph[u].append(v)
        graph[v].append(u)
    
    visited = set()
    components = 0
    
    for i in range(n):
        if i not in visited:
            dfs(graph, i, visited)
            components += 1
    return components

def dfs(graph, start, visited):
    stack = [start]
    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                if neighbor not in visited:
                    stack.append(neighbor)

n = int(input())
m = int(input())
edges = [tuple(map(int, input().split())) for _ in range(m)]

print(count_components(n, edges))

# %% [markdown]
# ## Заключение

# %% [markdown]
# Этот ноутбук — ваш универсальный шаблон. Используйте его как чек-лист при решении задач. Практикуйтесь, и вы станете лучше!
